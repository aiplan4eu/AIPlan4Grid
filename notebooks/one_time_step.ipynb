# %%
import os

os.chdir("../dist/")
# %pip install plan4grid-0.0.5-py3-none-any.whl
os.chdir("..")
from plan4grid import Launcher
# Out:
# Processing d:\aiplan4grid\dist\plan4grid-0.0.5-py3-none-any.whl
# Requirement already satisfied: Grid2Op in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (1.9.5)
# Requirement already satisfied: numba==0.56.4 in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (0.56.4)
# Requirement already satisfied: numpy==1.23.5 in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (1.23.5)
# Requirement already satisfied: pandapower==2.13.1 in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (2.13.1)
# Requirement already satisfied: unified-planning==1.0.0 in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (1.0.0)
# Requirement already satisfied: up-enhsp==0.0.15 in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (0.0.15)
# Requirement already satisfied: matplotlib in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (3.8.0)
# Requirement already satisfied: ipykernel in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (6.25.2)
# Requirement already satisfied: tqdm in d:\aiplan4grid\.venv\lib\site-packages (from plan4grid==0.0.5) (4.66.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in d:\aiplan4grid\.venv\lib\site-packages (from numba==0.56.4->plan4grid==0.0.5) (0.39.1)
# Requirement already satisfied: setuptools in d:\aiplan4grid\.venv\lib\site-packages (from numba==0.56.4->plan4grid==0.0.5) (68.2.0)
# Requirement already satisfied: pandas>=1.0 in d:\aiplan4grid\.venv\lib\site-packages (from pandapower==2.13.1->plan4grid==0.0.5) (2.1.0)
# Requirement already satisfied: networkx>=2.5 in d:\aiplan4grid\.venv\lib\site-packages (from pandapower==2.13.1->plan4grid==0.0.5) (3.1)
# Requirement already satisfied: scipy in d:\aiplan4grid\.venv\lib\site-packages (from pandapower==2.13.1->plan4grid==0.0.5) (1.11.2)
# Requirement already satisfied: packaging in d:\aiplan4grid\.venv\lib\site-packages (from pandapower==2.13.1->plan4grid==0.0.5) (23.1)
# Requirement already satisfied: deepdiff in d:\aiplan4grid\.venv\lib\site-packages (from pandapower==2.13.1->plan4grid==0.0.5) (6.5.0)
# Requirement already satisfied: pyparsing in d:\aiplan4grid\.venv\lib\site-packages (from unified-planning==1.0.0->plan4grid==0.0.5) (3.1.1)
# Requirement already satisfied: requests>=2.23.0 in d:\aiplan4grid\.venv\lib\site-packages (from Grid2Op->plan4grid==0.0.5) (2.31.0)
# Requirement already satisfied: colorama in d:\aiplan4grid\.venv\lib\site-packages (from tqdm->plan4grid==0.0.5) (0.4.6)
# Requirement already satisfied: comm>=0.1.1 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (1.8.0)
# Requirement already satisfied: ipython>=7.23.1 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (8.15.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (0.1.6)
# Requirement already satisfied: nest-asyncio in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (1.5.8)
# Requirement already satisfied: psutil in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in d:\aiplan4grid\.venv\lib\site-packages (from ipykernel->plan4grid==0.0.5) (5.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (10.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in d:\aiplan4grid\.venv\lib\site-packages (from matplotlib->plan4grid==0.0.5) (2.8.2)
# Requirement already satisfied: backcall in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.2.0)
# Requirement already satisfied: decorator in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.19.0)
# Requirement already satisfied: pickleshare in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (2.16.1)
# Requirement already satisfied: stack-data in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.6.2)
# Requirement already satisfied: exceptiongroup in d:\aiplan4grid\.venv\lib\site-packages (from ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (1.1.3)
# Requirement already satisfied: platformdirs>=2.5 in d:\aiplan4grid\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->plan4grid==0.0.5) (3.10.0)
# Requirement already satisfied: pywin32>=300 in d:\aiplan4grid\.venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->plan4grid==0.0.5) (306)
# Requirement already satisfied: pytz>=2020.1 in d:\aiplan4grid\.venv\lib\site-packages (from pandas>=1.0->pandapower==2.13.1->plan4grid==0.0.5) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in d:\aiplan4grid\.venv\lib\site-packages (from pandas>=1.0->pandapower==2.13.1->plan4grid==0.0.5) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\aiplan4grid\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib->plan4grid==0.0.5) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\aiplan4grid\.venv\lib\site-packages (from requests>=2.23.0->Grid2Op->plan4grid==0.0.5) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\aiplan4grid\.venv\lib\site-packages (from requests>=2.23.0->Grid2Op->plan4grid==0.0.5) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\aiplan4grid\.venv\lib\site-packages (from requests>=2.23.0->Grid2Op->plan4grid==0.0.5) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in d:\aiplan4grid\.venv\lib\site-packages (from requests>=2.23.0->Grid2Op->plan4grid==0.0.5) (2023.7.22)
# Requirement already satisfied: ordered-set<4.2.0,>=4.0.2 in d:\aiplan4grid\.venv\lib\site-packages (from deepdiff->pandapower==2.13.1->plan4grid==0.0.5) (4.1.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in d:\aiplan4grid\.venv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.8.3)
# Requirement already satisfied: wcwidth in d:\aiplan4grid\.venv\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in d:\aiplan4grid\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in d:\aiplan4grid\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (2.4.0)
# Requirement already satisfied: pure-eval in d:\aiplan4grid\.venv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->plan4grid==0.0.5) (0.2.2)
# Installing collected packages: plan4grid
# Successfully installed plan4grid-0.0.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
env_name = "educ_case14_storage"
scenario_id = 3
tactical_horizon = 1
debug = False

# %%
launcher = Launcher(env_name, scenario_id, tactical_horizon, debug=debug)
launcher.launch()
# Out:
# Running the agent on scenario 3 for 288 steps of 5 minutes.
# Steps: 100%|██████████| 288/288 [00:17<00:00, 16.52it/s]
# Total reward: 4373.93052482605
# Logs are available in D:\AIPlan4Grid\log\AIPlan4GridAgent.log
