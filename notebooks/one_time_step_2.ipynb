# %% [markdown]
# In this notebook we are going to see that the single time step approach will fail on scenario 1.

# %%
from plan4grid import Launcher

# %%
env_name = "educ_case14_storage"
scenario_id = 1
tactical_horizon = 1
launcher = Launcher(env_name=env_name, scenario_id=scenario_id, tactical_horizon=tactical_horizon)

# %%
launcher.launch(save=False)
# Out:
# Running the agent on scenario 1 for 288 steps of 5 minutes.
# Steps:  80%|███████▉  | 230/288 [00:17<00:04, 12.84it/s]
# Total reward: 3539.68590259552
# Logs are available in C:\Users\mdeboute\Desktop\AIPlan4Grid\demo\.venv\Lib\site-packages\log\AIPlan4GridAgent.log

# %% [markdown]
# Here you can see that the program stopped at 80% and ends up on a blackout.
#
# After analysing the logs, we can see that the agent is trying to stem the congestion, that is gradually appearing, by discharging the batteries. This works for a while, but then the problems get worse and the blackout occurs.
